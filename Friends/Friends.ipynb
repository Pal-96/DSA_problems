# %% [markdown]
# # copyright: Jagadeesh Vasudevamurthy
# # Frie:  Friends.ipynb

# %% [markdown]
# # WRITE CODE ONLY IN THIS CELL

# %%
############################################################
# Solution.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################

############################################################
# All imports
###########################################################
##from Util import *

class Solution:
  def __init__(self,n:'int',a:'list of size 2'):
    self._n = n
    #a[0] = How many friends are there in n. Use _increment_number_of_friends to fill
    #a[1] = num_steps Use _increment_steps
    self._list = a
    ##YOU CAN HAVE ANY NUMBER OF DATA STRUCTURES HERE
    self._u = Util()
    self._record = []
    

    ## NOTHING CAN BE CHANGED BELOW
    self._alg()

  def _increment_steps(self)->'none':
    self._list[1] = self._list[1] + 1

  def _increment_number_of_friends(self)->"int":
    self._list[0] = self._list[0] + 1
    return (self._list[0])


  ##Implement your code BELOW
  ##You can have any number of private variables and functions

  def _alg(self):
    print("WRITE CODE")
    print("Write as many small functions as possible")
    self._initialize_record()
    self._find_all_factors()
    self._find_friends()
    
  def _initialize_record(self):
        for i in range(self._n + 1):
            self._record.append(1)
            self._increment_steps()
        self._record[0] = 0
        
  def _find_all_factors(self):
        for i in range(2, self._u.sqrt_upper_bound(self._n)):
            k = i
            while True:
                self._increment_steps()
                j = i * k
                if j > self._n:
                    break
                elif i == k:
                    self._record[j] = self._record[j] + k
                else:
                    self._record[j] = self._record[j] + k + i
                k += 1
  def _find_friends(self):
        for i in range(self._n+1):
            self._increment_steps()
            sum_factors = self._record[i]
            if sum_factors<=self._n and sum_factors>i and self._record[sum_factors] == i:
                self._increment_number_of_friends()

# %% [markdown]
# # Some useful function
# # Can use if required

# %%
############################################################
# Util.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2020
###########################################################

############################################################
# NOTHING CAN BE CHANGED IN THIS FILE
###########################################################

############################################################
# All imports
###########################################################
import sys # For getting Python Version
import random 
import math
from time import process_time 

class Util():
  pass


  ############################################
  # log to the next possible integer
  #########################################
  def log_upper_bound(self, n:'int', b:'int')->'int':
    f = math.log(n,b)
    c = math.ceil(f)
    return c 

  ############################################
  # log to the smallest possible integer
  #########################################
  def log_lower_bound(self, n:'int', b:'int')->'int':
    f = math.log(n,b)
    c = math.floor(f)
    return c 

  ############################################
  # sqrt to the next possible integer
  #########################################
  def sqrt_upper_bound(self, n:'int')->'int':
    f = math.sqrt(n)
    c = math.ceil(f)
    return c

# %% [markdown]
# # TEST BENCH
# # NOTHING CAN BE CHANGED BELOW

# %%
############################################################
# Friends.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2023
###########################################################

############################################################
#           NOTHING CAN BE CHANGED IN THIS FILE
###########################################################

############################################################
# All imports
###########################################################
#from Util import *
#from Solution import *


class Friends():
  def __init__(self):
    self._u = Util()
    self._testBench()

  def _testBench(self):
    self._tests()
    print("ALL TESTS PASSED")

  def _test1(self,n:'int',ans:'int'):
    print("-------------", n , "-------------------------")
    a = [0,0]
    t1_start = process_time()
    s = Solution(n,a) ##All action happens here
    t1_stop = process_time() 
    if (a[1] == 0):
        print("How did you solve the problem in 0 steps")
        print("when ever you loop call _increment_steps() ")
        assert(False)
    if (a[0] == 0):
        print("Number of friends is 0. How?")
        print("when ever you find friend call _increment_number_of_friends ")
        assert(False)
    d = t1_stop - t1_start; 
    print(n, " has ", a[0], " friends. Took", a[1], " steps to compute")
    print("Total CPU time in sec =",d)
    logn_base2 = self._u.log_lower_bound(n,2)
    nlogn = n * logn_base2
    w = a[1] / nlogn 
    print("n = ", n)
    print("logn ", logn_base2)
    print("nlogn ",nlogn)
    print("num_steps/nlogn", w)
    if (a[0] != ans):
      print(n," Has", ans, "Friends. But you are telling",a[0])
      assert(a[0] == ans)


  def _tests(self):
    n = 10000
    a = self._test1(n,5)

    n = 20000
    a = self._test1(n,8)

    n = 100000000 ## YOU CANNOT CHANGE THIS.
    a = self._test1(n,231)


############################################################
# main 
# YOU CANNOT CHANGE ANYTHING BELOW
###########################################################
def main():
  print("Testing Friends.py Starts")
  s = Friends()
  print("Testing Friends.py ENDS")

############################################################
# Pthin calls this
###########################################################
if (__name__  == '__main__'):
  main()
# Out:
# Testing Friends.py Starts
# ------------- 10000 -------------------------
# WRITE CODE
# Write as many small functions as possible
# 10000  has  5  friends. Took 56983  steps to compute
# Total CPU time in sec = 0.03125
# n =  10000
# logn  13
# nlogn  130000
# num_steps/nlogn 0.43833076923076925
# ------------- 20000 -------------------------
# WRITE CODE
# Write as many small functions as possible
# 20000  has  8  friends. Took 120801  steps to compute
# Total CPU time in sec = 0.046875
# n =  20000
# logn  14
# nlogn  280000
# num_steps/nlogn 0.4314321428571429
# ------------- 100000000 -------------------------
# WRITE CODE
# Write as many small functions as possible
# 100000000  has  231  friends. Took 1028770783  steps to compute
# Total CPU time in sec = 557.84375
# n =  100000000
# logn  26
# nlogn  2600000000
# num_steps/nlogn 0.39568107038461536
# ALL TESTS PASSED
# Testing Friends.py ENDS
